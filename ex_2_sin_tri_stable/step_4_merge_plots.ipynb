# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import matplotlib as mpl
from cycler import cycler
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.transforms as mtransforms
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.lines as mlines

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['font.size'] = 30
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
plt.rcParams['axes.prop_cycle'] = cycler(alpha=[1])
mpl.rcParams['figure.figsize'] = [10 , 7]
mpl.rcParams['text.usetex'] = False
mpl.rcParams['legend.frameon'] = False
mpl.rcParams['legend.edgecolor'] = 'k'
mpl.rcParams['legend.framealpha'] = 1
mpl.rcParams['legend.fancybox'] = False

ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#797c82', '#9A33BB']

# %%
bi_stable_RNCRN_traj_10=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_10=np.asarray(bi_stable_RNCRN_traj_10) 


bi_stable_non_kinetic_traj_10=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_10=np.asarray(bi_stable_non_kinetic_traj_10) 

#7
bi_stable_RNCRN_traj_7=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_7=np.asarray(bi_stable_RNCRN_traj_7) 


bi_stable_non_kinetic_traj_7=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_7=np.asarray(bi_stable_non_kinetic_traj_7) 

#4
bi_stable_RNCRN_traj_4=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_4=np.asarray(bi_stable_RNCRN_traj_4) 


bi_stable_non_kinetic_traj_4=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_4=np.asarray(bi_stable_non_kinetic_traj_4) 


#1
bi_stable_RNCRN_traj_1=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_1=np.asarray(bi_stable_RNCRN_traj_1) 


bi_stable_non_kinetic_traj_1=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_1=np.asarray(bi_stable_non_kinetic_traj_1) 


#14
bi_stable_RNCRN_traj_14=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_14=np.asarray(bi_stable_RNCRN_traj_14) 


bi_stable_non_kinetic_traj_14=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_14=np.asarray(bi_stable_non_kinetic_traj_14) 


#17
bi_stable_RNCRN_traj_17=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_traj_17=np.asarray(bi_stable_RNCRN_traj_17) 


bi_stable_non_kinetic_traj_17=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_non_kinetic_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_non_kinetic_traj_17=np.asarray(bi_stable_non_kinetic_traj_17) 





#Vector field
bi_stable_RNCRN_Simulation_Dynam=[]
with open('../ex_1_sin_bi_stable/data/bi_stable_RNCRN_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_RNCRN_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_RNCRN_Simulation_Dynam=np.asarray(bi_stable_RNCRN_Simulation_Dynam) 


bi_stable_NonKin_Simulation_Dynam =[]
with open('../ex_1_sin_bi_stable/data/bi_stable_non_kinetic_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        bi_stable_NonKin_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
bi_stable_NonKin_Simulation_Dynam=np.asarray(bi_stable_NonKin_Simulation_Dynam)

# %%
tri_stable_RNCRN_traj_10=[]
with open('data/tri_stable_RNCRN_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_10=np.asarray(tri_stable_RNCRN_traj_10) 


tri_stable_non_kinetic_traj_10=[]
with open('data/tri_stable_non_kinetic_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_10=np.asarray(tri_stable_non_kinetic_traj_10) 

#7
tri_stable_RNCRN_traj_7=[]
with open('data/tri_stable_RNCRN_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_7=np.asarray(tri_stable_RNCRN_traj_7) 


tri_stable_non_kinetic_traj_7=[]
with open('data/tri_stable_non_kinetic_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_7=np.asarray(tri_stable_non_kinetic_traj_7) 

#4
tri_stable_RNCRN_traj_4=[]
with open('data/tri_stable_RNCRN_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_4=np.asarray(tri_stable_RNCRN_traj_4) 


tri_stable_non_kinetic_traj_4=[]
with open('data/tri_stable_non_kinetic_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_4=np.asarray(tri_stable_non_kinetic_traj_4) 


#1
tri_stable_RNCRN_traj_1=[]
with open('data/tri_stable_RNCRN_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_1=np.asarray(tri_stable_RNCRN_traj_1) 


tri_stable_non_kinetic_traj_1=[]
with open('data/tri_stable_non_kinetic_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_1=np.asarray(tri_stable_non_kinetic_traj_1) 


#14
tri_stable_RNCRN_traj_14=[]
with open('data/tri_stable_RNCRN_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_14=np.asarray(tri_stable_RNCRN_traj_14) 


tri_stable_non_kinetic_traj_14=[]
with open('data/tri_stable_non_kinetic_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_14=np.asarray(tri_stable_non_kinetic_traj_14) 


#17
tri_stable_RNCRN_traj_17=[]
with open('data/tri_stable_RNCRN_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_17=np.asarray(tri_stable_RNCRN_traj_17) 


tri_stable_non_kinetic_traj_17=[]
with open('data/tri_stable_non_kinetic_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_17=np.asarray(tri_stable_non_kinetic_traj_17) 


#Vector field
tri_stable_RNCRN_Simulation_Dynam=[]
with open('data/tri_stable_RNCRN_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_Simulation_Dynam=np.asarray(tri_stable_RNCRN_Simulation_Dynam) 


tri_stable_NonKin_Simulation_Dynam =[]
with open('data/tri_stable_non_kinetic_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_NonKin_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_NonKin_Simulation_Dynam=np.asarray(tri_stable_NonKin_Simulation_Dynam)

# %%
stablefp = 'limegreen'
linestyle_nodes = '-'
mpl.rcParams['figure.figsize'] = [24 , 14]
ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#bbbdbf']
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['font.size'] = 30

fig, axs = plt.subplot_mosaic([['.', '(a)', '(b)', '.'],['.','(c)', '(d)','.']],  gridspec_kw={ 'width_ratios':[1,2,2,1], 'hspace':0.06, 'wspace':0.06},layout='constrained')
for label, ax in axs.items():
    # label physical distance to the left and up:
    trans = mtransforms.ScaledTranslation(-40/72, 14/72, fig.dpi_scale_trans)
    if label != '.':
        ax.text(0.0, 1.0, label, transform=ax.transAxes + trans,
                fontsize='medium', va='bottom', fontfamily='serif', ha='right')
tickfontsize=30
labelfontsize=35
titlefontsize=35  
legendfontsize = 20;
markersizeval = 10
axa = axs['(a)']
axa.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
axa.plot(bi_stable_NonKin_Simulation_Dynam[:,0], bi_stable_NonKin_Simulation_Dynam[:,1],'-' ,color=ColList[0], label='$f(x_1)$')
axa.plot(bi_stable_RNCRN_Simulation_Dynam[:,0], bi_stable_RNCRN_Simulation_Dynam[:,1],'--' ,color=ColList[1], label='$g(x_1)$')
axa.set_yticks(np.arange(-5, 5, 1), fontsize=tickfontsize)
axa.set_xticks(np.arange(0, 9*np.pi, np.pi))
axa.set_xticklabels(['$0$','$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$', '$7\pi$', '$8\pi$'], fontsize=tickfontsize)
axa.tick_params(axis='both', which='major' )
axa.legend(fontsize=18)
axa.set_xlabel(r'State $x_1$', fontsize=labelfontsize )
axa.set_ylabel(r'Vector field', fontsize=labelfontsize)
axa.set_xlim(0,8*np.pi)
axa.set_ylim(-4.1, 4.1)
axa.vlines(1, -5, 5, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axa.vlines(12, -5, 5, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axa.tick_params(bottom=True, top=True, left=True, right=True)
axa.tick_params(bottom=True, top=True, left=True, right=True, which='minor')
axa.tick_params(axis="x", direction="in", labelsize=tickfontsize)
axa.tick_params(axis="y", direction="in", labelsize=tickfontsize)
axa.tick_params(axis="x", direction="in", which="minor")
axa.tick_params(axis="y", direction="in", which="minor")
axa.xaxis.set_minor_locator(AutoMinorLocator(2))
axa.yaxis.set_minor_locator(AutoMinorLocator(2))
axa.fill([12, 12, 25, 25], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axa.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axa.fill([12, 12, 25, 25], [-20, 20, 20, -20], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axa.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'None', alpha=0.1,edgecolor=ColList[3], hatch="/")
axa.set_title(r'Bi-stable dynamics', fontsize=titlefontsize, pad=15.5)
axa.legend(fontsize=legendfontsize, loc='upper right')

axb = axs['(b)']
axb.plot( bi_stable_non_kinetic_traj_1[:,0],  bi_stable_non_kinetic_traj_1[:,1],'-' ,color=ColList[0], label='$\\bar{x}_1(t)$')
axb.plot( bi_stable_RNCRN_traj_1[:,0],  bi_stable_RNCRN_traj_1[:,1],'--' , dashes=(5, 1), color=ColList[1], label='$x_1(t)$')
axb.plot( bi_stable_non_kinetic_traj_4[:,0],  bi_stable_non_kinetic_traj_4[:,1],'-' ,color=ColList[0])
axb.plot( bi_stable_RNCRN_traj_4[:,0],  bi_stable_RNCRN_traj_4[:,1],'--' , dashes=(5, 3),color=ColList[1])
axb.plot( bi_stable_non_kinetic_traj_7[:,0],  bi_stable_non_kinetic_traj_7[:,1],'-' ,color=ColList[0])
axb.plot( bi_stable_RNCRN_traj_7[:,0],  bi_stable_RNCRN_traj_7[:,1],'--', dashes=(5, 1) ,color=ColList[1])
axb.plot( bi_stable_non_kinetic_traj_10[:,0],  bi_stable_non_kinetic_traj_10[:,1],'-' ,color=ColList[0])
axb.plot( bi_stable_RNCRN_traj_10[:,0],  bi_stable_RNCRN_traj_10[:,1],'--', dashes=(5, 3) ,color=ColList[1])
axb.plot( bi_stable_RNCRN_traj_14[:,0],  bi_stable_RNCRN_traj_14[:,1],'--', dashes=(5, 5) ,color=ColList[1])
axb.plot( bi_stable_non_kinetic_traj_14[:,0],  bi_stable_non_kinetic_traj_14[:,1],'-' ,color=ColList[0])
axb.plot( bi_stable_RNCRN_traj_17[:,0],  bi_stable_RNCRN_traj_17[:,1],'--', dashes=(5, 7) ,color=ColList[1])
axb.plot( bi_stable_non_kinetic_traj_17[:,0],  bi_stable_non_kinetic_traj_17[:,1],'-' ,color=ColList[0])
axb.hlines(1, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axb.hlines(12, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axb.set_xticks([0,1,2,3,4,5,6,7], fontsize=tickfontsize)
axb.set_yticks(np.arange(0,22,5), fontsize=tickfontsize)
axb.tick_params(axis='both', which='major')
axb.set_ylabel(r'$x_1(t)$', fontsize=labelfontsize )
axb.set_xlabel(r'Time $t$', fontsize=labelfontsize )
axb.set_xlim(0,5)
axb.set_ylim(0, 8*np.pi)
axb.tick_params(bottom=True, top=True, left=True, right=True)
axb.tick_params(bottom=True, top=True, left=True, right=True, which='minor')
axb.tick_params(axis="x", direction="in", labelsize=tickfontsize)
axb.tick_params(axis="y", direction="in", labelsize=tickfontsize)
axb.tick_params(axis="x", direction="in", which="minor")
axb.tick_params(axis="y", direction="in", which="minor")
axb.xaxis.set_minor_locator(AutoMinorLocator(5))
axb.yaxis.set_minor_locator(AutoMinorLocator(2))
axb.set_yticks(np.arange(0, 9*np.pi, np.pi))
axb.set_yticklabels(['$0$','$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$','$7\pi$', '$8\pi$'], fontsize=tickfontsize)
axb.fill([0, 0, 20, 20], [12, 25, 25, 12], color = 'gray', alpha=0.1)
axb.fill([0, 0, 20, 20], [12, 25, 25, 12], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axb.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'gray', alpha=0.1)
axb.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axb.set_title(r'Bi-stable trajectories', fontsize=titlefontsize,pad=15.5)
axb.legend(fontsize=legendfontsize, loc='upper right')

axc = axs['(c)']
axc.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
axc.plot(tri_stable_NonKin_Simulation_Dynam[:,0], tri_stable_NonKin_Simulation_Dynam[:,1],'-' ,color=ColList[0], label='$f(x_1)$')
axc.plot(tri_stable_RNCRN_Simulation_Dynam[:,0], tri_stable_RNCRN_Simulation_Dynam[:,1], linestyle='--' ,color=ColList[1], label='$g(x_1)$')
axc.set_xticks(np.arange(0, 9*np.pi, np.pi))
axc.set_xticklabels(['$0$','$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$', '$7\pi$', '$8\pi$'], fontsize=tickfontsize)
axc.set_yticks(np.arange(-5, 5, 1))
axc.tick_params(axis='both', which='major' )
axc.set_xlabel(r'State $x_1$', fontsize=labelfontsize )
axc.set_ylabel(r'Vector field', fontsize=labelfontsize )
axc.set_xlim(0,8*np.pi)
axc.set_ylim(-4.1, 4.1)
axc.vlines(1, -5, 5, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axc.vlines(18, -5, 5, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axc.tick_params(bottom=True, top=True, left=True, right=True)
axc.tick_params(bottom=True, top=True, left=True, right=True, which='minor')
axc.tick_params(axis="x", direction="in", labelsize=tickfontsize)
axc.tick_params(axis="y", direction="in", labelsize=tickfontsize)
axc.tick_params(axis="x", direction="in", which="minor")
axc.tick_params(axis="y", direction="in", which="minor")
axc.xaxis.set_minor_locator(AutoMinorLocator(2))
axc.yaxis.set_minor_locator(AutoMinorLocator(2))
axc.fill([18, 18, 25, 25], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axc.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axc.fill([18, 18, 25, 25], [-20, 20, 20, -20], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axc.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'None', alpha=0.1,edgecolor=ColList[3], hatch="/")
axc.set_title(r'Tri-stable dynamics', fontsize=titlefontsize, pad=15.5)
axc.legend(fontsize=legendfontsize, loc='upper right')

axd = axs['(d)']
axd.plot( tri_stable_non_kinetic_traj_1[:,0],  tri_stable_non_kinetic_traj_1[:,1],'-' ,color=ColList[0], label='$\\bar{x}_1(t)$')
axd.plot( tri_stable_RNCRN_traj_1[:,0],  tri_stable_RNCRN_traj_1[:,1],linestyle='--', dashes=(5, 1) ,color=ColList[1], label='$x_1(t)$')
axd.plot( tri_stable_non_kinetic_traj_4[:,0],  tri_stable_non_kinetic_traj_4[:,1],'-' ,color=ColList[0])
axd.plot( tri_stable_RNCRN_traj_4[:,0],  tri_stable_RNCRN_traj_4[:,1],linestyle='--', dashes=(5, 3) ,color=ColList[1])
axd.plot( tri_stable_non_kinetic_traj_7[:,0],  tri_stable_non_kinetic_traj_7[:,1],'-' ,color=ColList[0])
axd.plot( tri_stable_RNCRN_traj_7[:,0],  tri_stable_RNCRN_traj_7[:,1],linestyle='--', dashes=(5, 1) ,color=ColList[1])
axd.plot( tri_stable_non_kinetic_traj_10[:,0],  tri_stable_non_kinetic_traj_10[:,1],'-' ,color=ColList[0])
axd.plot( tri_stable_RNCRN_traj_10[:,0],  tri_stable_RNCRN_traj_10[:,1],linestyle='--', dashes=(5, 3) ,color=ColList[1])
axd.plot( tri_stable_non_kinetic_traj_14[:,0],  tri_stable_non_kinetic_traj_14[:,1],'-' ,color=ColList[0])
axd.plot( tri_stable_RNCRN_traj_14[:,0],  tri_stable_RNCRN_traj_14[:,1],linestyle='--', dashes=(5, 1) ,color=ColList[1])
axd.plot( tri_stable_non_kinetic_traj_17[:,0],  tri_stable_non_kinetic_traj_17[:,1],'-' ,color=ColList[0])
axd.plot( tri_stable_RNCRN_traj_17[:,0],  tri_stable_RNCRN_traj_17[:,1],linestyle='--' , dashes=(5, 3), color=ColList[1])
axd.hlines(1, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='--' )
axd.hlines(18, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='--' )
axd.set_xticks(np.arange(0,8,1))
axd.set_yticks(np.arange(0, 9*np.pi, np.pi))
axd.set_yticklabels(['$0$','$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$', '$7\pi$', '$8\pi$'], fontsize=labelfontsize)
axd.tick_params(axis='both', which='major')
axd.set_xlabel(r'Time $t$', fontsize=labelfontsize )
axd.set_ylabel(r'$x_1(t)$', fontsize=labelfontsize )
axd.set_xlim(0,5)
axd.set_ylim(0, 8*np.pi)
axd.set_ymargin(10)
axd.tick_params(bottom=True, top=True, left=True, right=True)
axd.tick_params(bottom=True, top=True, left=True, right=True, which='minor')
axd.tick_params(axis="x", direction="in", labelsize=tickfontsize)
axd.tick_params(axis="y", direction="in", labelsize=tickfontsize)
axd.tick_params(axis="x", direction="in", which="minor")
axd.tick_params(axis="y", direction="in", which="minor")
axd.xaxis.set_minor_locator(AutoMinorLocator(5))
axd.yaxis.set_minor_locator(AutoMinorLocator(2))
axd.fill([0, 0, 20, 20], [18, 25, 25, 18], color = 'gray', alpha=0.1)
axd.fill([0, 0, 20, 20], [18, 25, 25, 18], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axd.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'gray', alpha=0.1)
axd.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axd.set_title(r'Tri-stable trajectories', fontsize=titlefontsize,pad=15.5)
axd.legend(fontsize=legendfontsize, loc='upper right')

fig.savefig('figures/figure_2.pdf', bbox_inches='tight', dpi=fig.dpi)
plt.show()
