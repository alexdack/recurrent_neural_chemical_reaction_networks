# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import matplotlib as mpl
from cycler import cycler
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.transforms as mtransforms
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.lines as mlines

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['font.size'] = 30
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.serif'] = 'Times New Roman'
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'serif'
plt.rcParams['axes.prop_cycle'] = cycler(alpha=[1])
mpl.rcParams['figure.figsize'] = [12 , 5]
mpl.rcParams['text.usetex'] = False
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['legend.edgecolor'] = 'k'
mpl.rcParams['legend.framealpha'] = 1
mpl.rcParams['legend.fancybox'] = False

ColList = ['#1F13FF','#FF00D0', '#2A2A72', '#797c82']

# %%
tri_stable_RNCRN_traj_10=[]
with open('data/tri_stable_RNCRN_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_10=np.asarray(tri_stable_RNCRN_traj_10) 


tri_stable_non_kinetic_traj_10=[]
with open('data/tri_stable_non_kinetic_traj_10.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_10.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_10=np.asarray(tri_stable_non_kinetic_traj_10) 

#7
tri_stable_RNCRN_traj_7=[]
with open('data/tri_stable_RNCRN_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_7=np.asarray(tri_stable_RNCRN_traj_7) 


tri_stable_non_kinetic_traj_7=[]
with open('data/tri_stable_non_kinetic_traj_7.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_7.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_7=np.asarray(tri_stable_non_kinetic_traj_7) 

#4
tri_stable_RNCRN_traj_4=[]
with open('data/tri_stable_RNCRN_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_4=np.asarray(tri_stable_RNCRN_traj_4) 


tri_stable_non_kinetic_traj_4=[]
with open('data/tri_stable_non_kinetic_traj_4.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_4.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_4=np.asarray(tri_stable_non_kinetic_traj_4) 


#1
tri_stable_RNCRN_traj_1=[]
with open('data/tri_stable_RNCRN_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_1=np.asarray(tri_stable_RNCRN_traj_1) 


tri_stable_non_kinetic_traj_1=[]
with open('data/tri_stable_non_kinetic_traj_1.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_1.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_1=np.asarray(tri_stable_non_kinetic_traj_1) 


#14
tri_stable_RNCRN_traj_14=[]
with open('data/tri_stable_RNCRN_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_14=np.asarray(tri_stable_RNCRN_traj_14) 


tri_stable_non_kinetic_traj_14=[]
with open('data/tri_stable_non_kinetic_traj_14.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_14.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_14=np.asarray(tri_stable_non_kinetic_traj_14) 


#17
tri_stable_RNCRN_traj_17=[]
with open('data/tri_stable_RNCRN_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_RNCRN_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_RNCRN_traj_17=np.asarray(tri_stable_RNCRN_traj_17) 


tri_stable_non_kinetic_traj_17=[]
with open('data/tri_stable_non_kinetic_traj_17.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        tri_stable_non_kinetic_traj_17.append([float(datapoint) for datapoint in row[0].split(',')])
        
tri_stable_non_kinetic_traj_17=np.asarray(tri_stable_non_kinetic_traj_17) 


#Vector field
RNCRN_Simulation_Dynam=[]
with open('data/tri_stable_RNCRN_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        RNCRN_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
RNCRN_Simulation_Dynam=np.asarray(RNCRN_Simulation_Dynam) 


NonKin_Simulation_Dynam =[]
with open('data/tri_stable_non_kinetic_dynam.csv',newline='') as csvfile:
    data = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in data:
        NonKin_Simulation_Dynam.append([float(datapoint) for datapoint in row[0].split(',')])
        
NonKin_Simulation_Dynam=np.asarray(NonKin_Simulation_Dynam)

# %%
fig, axs = plt.subplot_mosaic([['(a)', '(b)']],
                              layout='constrained')
mpl.rcParams['legend.frameon'] = False

for label, ax in axs.items():
    # label physical distance to the left and up:
    trans = mtransforms.ScaledTranslation(-40/72, 14/72, fig.dpi_scale_trans)
    ax.text(0.0, 1.0, label, transform=ax.transAxes + trans,
            fontsize='medium', va='bottom', fontfamily='serif', ha='right')

labelfontsize = 15;    
stablefp = 'limegreen'

axa = axs['(a)']
axa.axhline(y=0, color='k', linestyle='-', linewidth=0.5)
axa.axvline(x=np.pi, ymin=0.5, color=stablefp, linestyle='--', linewidth=1.5)
axa.axvline(x=2*np.pi, ymin=0.5, color='red', linestyle='--', linewidth=1.5)
axa.axvline(x=3*np.pi, ymin=0.5, color=stablefp, linestyle='--', linewidth=1.5)
axa.axvline(x=4*np.pi, ymin=0.5, color='red', linestyle='--', linewidth=1.5)
axa.axvline(x=5*np.pi, ymin=0.5, color=stablefp, linestyle='--', linewidth=1.5)
axa.plot(NonKin_Simulation_Dynam[:,0], NonKin_Simulation_Dynam[:,1],'-' ,color=ColList[0])
axa.plot(RNCRN_Simulation_Dynam[:,0], RNCRN_Simulation_Dynam[:,1],'--' ,color=ColList[1])
axa.set_xticks(np.arange(0,22, 5))
axa.set_yticks([-1,-0.5, 0, 0.5, 1])
axa.tick_params(axis='both', which='major' )
axa.legend(fontsize=18)
axa.set_xlabel(r'State $x_1$' )
axa.set_ylabel(r'Vector field' )
axa.set_xlim(0,21)
axa.set_ylim(-1.1, 1.1)
axa.legend(fontsize=20, loc='upper right')
axa.vlines(1, -2, 2, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axa.vlines(18, -2, 2, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axa.plot(np.pi, 0, 'o', color=stablefp)
axa.plot(2*np.pi, 0, 'o', color='red')
axa.plot(3*np.pi, 0, 'o', color=stablefp)
axa.plot(4*np.pi, 0, 'o', color='red')
axa.plot(5*np.pi, 0, 'o', color=stablefp)
axa.tick_params(bottom=True, top=False, left=True, right=True)
axa.tick_params(bottom=True, top=False, left=True, right=True, which='minor')
axa.tick_params(axis="x", direction="in", labelsize=labelfontsize)
axa.tick_params(axis="y", direction="in", labelsize=labelfontsize)
axa.tick_params(axis="x", direction="in", which="minor")
axa.tick_params(axis="y", direction="in", which="minor")
axa.xaxis.set_minor_locator(AutoMinorLocator(5))
axa.yaxis.set_minor_locator(AutoMinorLocator(2))
axa.fill([18, 18, 25, 25], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axa.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'gray', alpha=0.1)
axa.fill([18, 18, 25, 25], [-20, 20, 20, -20], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axa.fill([0, 0, 1, 1], [-20, 20, 20, -20], color = 'None', alpha=0.1,edgecolor=ColList[3], hatch="/")
axa_2 = axa.twiny();
axa_2.set_xticks(np.arange(0, 7*np.pi, np.pi))
axa_2.set_xticklabels(['0','$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$'], fontsize=labelfontsize)
axa_2.tick_params(bottom=False, top=True, left=False, right=False, which='minor')
axa_2.tick_params(axis="x", direction="in", labelsize=labelfontsize)
axa_2.tick_params(axis="x", direction="in", which="minor")
axa_2.xaxis.set_minor_locator(AutoMinorLocator(2))
axa_2.set_xlim(0,21)


axb = axs['(b)']
axb.axhline(y=np.pi, color=stablefp, linestyle='--', linewidth=2.5)
axb.axhline(y=2*np.pi, color='red', linestyle='--', linewidth=2.5)
axb.axhline(y=3*np.pi, color=stablefp, linestyle='--', linewidth=2.5)
axb.axhline(y=4*np.pi, color='red', linestyle='--', linewidth=2.5)
axb.axhline(y=5*np.pi, color=stablefp, linestyle='--', linewidth=2.5)
axb.plot( tri_stable_non_kinetic_traj_1[:,0],  tri_stable_non_kinetic_traj_1[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_1[:,0],  tri_stable_RNCRN_traj_1[:,1],'--' ,color=ColList[1])
axb.plot( tri_stable_non_kinetic_traj_4[:,0],  tri_stable_non_kinetic_traj_4[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_4[:,0],  tri_stable_RNCRN_traj_4[:,1],'--' ,color=ColList[1])
axb.plot( tri_stable_non_kinetic_traj_7[:,0],  tri_stable_non_kinetic_traj_7[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_7[:,0],  tri_stable_RNCRN_traj_7[:,1],'--' ,color=ColList[1])
axb.plot( tri_stable_non_kinetic_traj_10[:,0],  tri_stable_non_kinetic_traj_10[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_10[:,0],  tri_stable_RNCRN_traj_10[:,1],'--' ,color=ColList[1])
axb.plot( tri_stable_non_kinetic_traj_14[:,0],  tri_stable_non_kinetic_traj_14[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_14[:,0],  tri_stable_RNCRN_traj_14[:,1],'--' ,color=ColList[1])
axb.plot( tri_stable_non_kinetic_traj_17[:,0],  tri_stable_non_kinetic_traj_17[:,1],'-' ,color=ColList[0])
axb.plot( tri_stable_RNCRN_traj_17[:,0],  tri_stable_RNCRN_traj_17[:,1],'--' ,color=ColList[1])
axb.hlines(1, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axb.hlines(18, 0, 20, facecolor ='white', edgecolor='k', linewidth=1.5, linestyle='dashdot' )
axb.set_xticks([0,5,10,15,20])
axb.set_yticks(np.arange(0,22,5))
axb.tick_params(axis='both', which='major')
axb.legend(fontsize=18, loc='upper right')
axb.set_xlabel(r'Time $t$' )
axb.set_ylabel(r'$x_1(t)$' )
axb.set_xlim(0,20)
axb.set_ylim(0, 21)
axb.tick_params(bottom=True, top=True, left=True, right=True)
axb.tick_params(bottom=True, top=True, left=False, right=False, which='minor')
axb.tick_params(axis="x", direction="in", labelsize=labelfontsize)
axb.tick_params(axis="y", direction="in", labelsize=labelfontsize)
axb.tick_params(axis="x", direction="in", which="minor")
axb.tick_params(axis="y", direction="in", which="minor")
axb.xaxis.set_minor_locator(AutoMinorLocator(5))
axb.yaxis.set_minor_locator(AutoMinorLocator(5))
axb.fill([0, 0, 20, 20], [18, 25, 25, 18], color = 'gray', alpha=0.1)
axb.fill([0, 0, 20, 20], [18, 25, 25, 18], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axb.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'gray', alpha=0.1)
axb.fill([0, 0, 20, 20], [0, 1, 1, 0], color = 'None', alpha=0.1, edgecolor=ColList[3], hatch="/")
axb_2 = axb.twinx();
axb_2.set_yticks(np.arange(np.pi, 7*np.pi, np.pi))
axb_2.set_yticklabels(['$\pi$', '$2\pi$', '$3\pi$', '$4\pi$', '$5\pi$', '$6\pi$'], fontsize=labelfontsize)
axb_2.tick_params(bottom=False, top=False, left=False, right=True, which='minor')
axb_2.tick_params(axis="y", direction="in", labelsize=labelfontsize)
axb_2.tick_params(axis="y", direction="in", which="minor")
axb_2.yaxis.set_minor_locator(AutoMinorLocator(2))
axb_2.set_ylim(0,21)


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
